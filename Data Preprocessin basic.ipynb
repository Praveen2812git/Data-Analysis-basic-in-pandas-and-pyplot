# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
data1 = pd.read_csv('C:/Users/Praveen/Desktop/college_1.csv')
data2 = pd.read_csv('C:/Users/Praveen/Desktop/college_2.csv')
df = pd.concat([data1, data2], sort = False, ignore_index = True)
df
# Out:
#                        Name  python   mysql  Previous Geekions  \
# 0                 A.Dharani    82.0   20.00              24500
# 1               V.JEEVITHA     82.0   20.00              21740
# 2               HEMAVATHI.R   100.0  100.00              19680
# 3               Mugunthan S   100.0   47.00              10610
# 4               Sathammai.S   100.0    8.00               8980
# 5              NIVEESHWAR S   100.0    0.00               8200
# 6             KALAIARASAN K    85.0   47.00               7750
# 7      MOHAMED ZUBAIR AHMED    82.0    4.00               7020
# 8                J.SUGANTHI    27.0   50.00               5860
# 9              thamizhpaana    29.0    0.00               5500
# 10          Iyappan Samiraj    50.0   24.00               5400
# 11             Ponniyamma.R   100.0   11.25               5380
# 12                SABAPATHI   100.0    0.00               5280
# 13                 RAGHAVAN   100.0    0.00               5120
# 14          Melvin Dukles.R    56.0   20.00               4800
# 15                 Pavithra   100.0  100.00               4600
# 16              PRIYANKA .S    85.0    4.00               4510
# 17              v.vithyasri   100.0   12.00               4370
# 18       Abirami Anbazhagan   100.0    0.00               4320
# 19             S.srinivasan   100.0   12.00               4090
# 20                 s.janani   100.0    0.00               3915
# 21             kamalishwari    32.0   20.00               3665
# 22                  Yuvasri   100.0  100.00               3460
# 23                   balaji    82.0    0.00               3280
# 24                  MEERA.M   100.0  100.00               3200
# 25                Tpavithra   100.0   24.00               3200
# 26            sri dharshini   100.0  100.00               3110
# 27                 shankari    87.5   20.00               3000
# 28            pooja priya.B   100.0  100.00               2570
# 29                  chithra   100.0    0.00               2410
# ..                      ...     ...     ...                ...
# 89               Poojitha Y     0.0   35.00               7210
# 90   Gowtham Chandrasekaran    -1.0    0.00               7250
# 91                Gowtham R    -1.0    4.00               8650
# 92                 shifak N    58.0    0.00               5180
# 93                  Balaji     -1.0   20.00               6170
# 94                 Rushitha    -1.0   62.00               7470
# 95     Balaraman Muthupandi    -1.0    0.00               7670
# 96                 JPradhap   100.0    0.00               7340
# 97            SRIRAMKUMAR B    -1.0    0.00               6400
# 98                Praneetha    -1.0  100.00               7170
# 99              Rahul Raj K    -1.0    0.00               6280
# 100                 Guhan S    -1.0   35.00               7310
# 101            Suryarajan S    -1.0   31.00               6710
# 102          Narasimhan Y L    -1.0    0.00               4800
# 103            Leelakrishna    -1.0    4.00               5300
# 104          PremsagarReddy    -1.0    0.00               5290
# 105               pradeeban    16.0   24.00               6060
# 106             santhoshini    -1.0    0.00               3910
# 107              MUKESH S M    -1.0    0.00               5200
# 108           P.GOVARDHANAN    -1.0    0.00               5050
# 109            SHAIK DANISH    -1.0    0.00               4050
# 110               sridhar.s    -1.0    0.00               3860
# 111       Vimalesh Fernando    -1.0    0.00               4170
# 5          NaN                     NaN
# 6          NaN                     NaN
# 7          NaN                     NaN
# 8          NaN                     NaN
# 9          NaN                     NaN
# 10         NaN                     NaN
# 11         NaN                     NaN
# 12         NaN                     NaN
# 13         NaN                     NaN
# 14         NaN                     NaN
# 15         NaN                     NaN
# 16         NaN                     NaN
# 17         NaN                     NaN
# 18         NaN                     NaN
# 19         NaN                     NaN
# 20         NaN                     NaN
# 21         NaN                     NaN
# 22         NaN                     NaN
# 23         NaN                     NaN
# 24         NaN                     NaN
# 25         NaN                     NaN
# 26         NaN                     NaN
# 27         NaN                     NaN
# 28         NaN                     NaN
# 29         NaN                     NaN
# ..         ...                     ...
# 89        78.0                     0.0
# 90         0.0                     3.0
# 91        60.0                     6.0
# 92         0.0                     0.0
# 93       100.0                     0.0
# 94        15.0                     9.0
# 95         9.0                     0.0
# 96         0.0                     0.0
# 97         0.0                     0.0
# 98        23.0                    -1.0
# 99         0.0                     0.0
# 100       72.0                    39.0
# 101       63.0                     0.0
# 102       -1.0                     0.0
# 103        6.0                     0.0
# 104       20.0                     0.0
# 105       20.0                     0.0
# 106       43.0                     0.0
# 107       46.0                     0.0
# 108       40.0                    -1.0
# 109       43.0                     0.0
# 110       52.0                     0.0
# 111        0.0                     0.0
# 112        0.0                     6.0
# 113       55.0                     6.0
# 114       -1.0                     0.0
# 115       52.0                    -1.0
# 116       49.0                    -1.0
# 117       20.0                    -1.0
# 118       -1.0                     0.0
#
# [119 rows x 9 columns]

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df[(df['CodeKata Score'] > 15000)].to_csv("Exceeded expectations.csv", index=False)
df[(df['CodeKata Score'] > 10000) & df['CodeKata Score'] < 15000].to_csv("Reached_expectations.csv", index=False)
df[(df['CodeKata Score'] > 7000) & df['CodeKata Score'] < 10000].to_csv("Needs_Improvement.csv", index=False)
df[(df['CodeKata Score'] < 7000)].to_csv("Unsatisfactory.csv", index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avgpgcs = df['Previous Geekions'].mean() - df['CodeKata Score'].mean()
print(f'Average of Previous Geekions and CodeKata Score is {avgpgcs}')
# Out:
# Average of Previous Geekions and CodeKata Score is -209.41176470588243

# %% [markdown]
# ###### No of students participated

# %%
nosp = df[df.columns[0]].count()
print(f'No of Students participated is {nosp}')
# Out:
# No of Students participated is 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
pca = (df['python'] == 100).mean()
msca = (df['mysql'] == 100).mean()
peca = (df['python_en'] == 100).mean()
cta = (df['computational_thinking'] == 100).mean()
print(f'Average Completion of Python is {pca}')
print(f'Average Completion of MySQl is {msca}')
print(f'Average Completion of Python English is {peca}')
print(f'Average Completion of Computational Thinking is {cta}')
# Out:
# Average Completion of Python is 0.3445378151260504
# Average Completion of MySQl is 0.11764705882352941
# Average Completion of Python English is 0.01680672268907563
# Average Completion of Computational Thinking is 0.0

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.nlargest(n=4, columns='Rising') # n = 4, because two persons having the same score
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
# 93             Balaji     -1.0   20.0               6170            8160
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
# 93   Electronics and Electrical Engineering    1990      100.0
#
#      computational_thinking
# 92                      0.0
# 86                      6.0
# 102                     0.0
# 93                      0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.nlargest(n=3, columns = 'Previous Geekions')
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df.groupby(['Department']).sum().plot(kind = 'pie', y = 'CodeKata Score', autopct = '%1.lf%%',
                                            colors = ['red', 'green', 'blue'], shadow = True, startangle = 120,
                                     title = 'Department vs CodeKata Score')

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
# Computer Science Department
df[df['Department'] == 'Computer Science and Engineering'].groupby(['Name']).max().plot(kind = 'bar', y = 'CodeKata Score',
                                            color = ['pink', 'silver', 'steelblue'], figsize = (16, 6))

plt.title('Computer Science Engineering\n CodeKata Score vs Name')
plt.xlabel('Name')
plt.ylabel('CodeKata Score')
plt.show()

# %%
# Electronics and Communication Department
df[df['Department'] == 'Electronics and Communication Engineering'].groupby(['Name']).max().plot(kind = 'bar', y = 'CodeKata Score',
                                            color = ['pink', 'silver', 'steelblue'], figsize = (12, 5))

plt.title('Electronics and Communication Engineering\n CodeKata Score vs Name')
plt.xlabel('Name')
plt.ylabel('CodeKata Score')
plt.show()

# %%
# Electronics and Electrical Department
df[df['Department'] == 'Electronics and Electrical Engineering'].groupby(['Name']).max().plot(kind = 'bar', y = 'CodeKata Score',
                                            color = ['pink', 'silver', 'steelblue'], figsize = (10, 5))

plt.title('Electronics and Electrical Engineering\n CodeKata Score vs Name')
plt.xlabel('Name')
plt.ylabel('CodeKata Score')
plt.show()
